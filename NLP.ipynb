# %%
from textblob import TextBlob

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
text = "Today is a beautiful day , Tomorrow looks like bad weather"
blob = TextBlob(text)
print(blob.sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/textblob/decorators.py:35, in requires_nltk_corpus.<locals>.decorated(*args, **kwargs)
#      34 try:
# ---> 35     return func(*args, **kwargs)
#      36 except LookupError as error:
#
# File ~/anaconda3/lib/python3.13/site-packages/textblob/tokenizers.py:60, in SentenceTokenizer.tokenize(self, text)
#      59 """Return a list of sentences."""
# ---> 60 return nltk.tokenize.sent_tokenize(text)
#
# File ~/anaconda3/lib/python3.13/site-packages/nltk/tokenize/__init__.py:119, in sent_tokenize(text, language)
#     110 """
#     111 Return a sentence-tokenized copy of *text*,
#     112 using NLTK's recommended sentence tokenizer
#    (...)
#     117 :param language: the model name in the Punkt corpus
#     118 """
# --> 119 tokenizer = _get_punkt_tokenizer(language)
# ...

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/iteradmin/nltk_data...
# [Sentence("Today is a beautiful day , Tomorrow looks like bad weather")]
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
text = "Today is a beautiful day . Tomorrow looks like bad weather"
blob = TextBlob(text)
print(blob.sentences)
print(blob.words)
# Out:
# [Sentence("Today is a beautiful day ."), Sentence("Tomorrow looks like bad weather")]
# ['Today', 'is', 'a', 'beautiful', 'day', 'Tomorrow', 'looks', 'like', 'bad', 'weather']

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
ex = TextBlob("My old computer is slow . my new one is fast.")
ex.sentences
# Out:
# [Sentence("My old computer is slow ."), Sentence("my new one is fast.")]

# %%
ex.tags
# Out:
# [('My', 'PRP$'),
#  ('old', 'JJ'),
#  ('computer', 'NN'),
#  ('is', 'VBZ'),
#  ('slow', 'JJ'),
#  ('my', 'PRP$'),
#  ('new', 'JJ'),
#  ('one', 'CD'),
#  ('is', 'VBZ'),
#  ('fast', 'RB')]

# %%
s = TextBlob("My dog is cute")
s.tags
# Out:
# [('My', 'PRP$'), ('dog', 'NN'), ('is', 'VBZ'), ('cute', 'JJ')]

# %%
blob.noun_phrases
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 blob.noun_phrases.type()
#
# AttributeError: 'WordList' object has no attribute 'type'

# %%
blob = TextBlob("My name is ram. I love cakes")
blob.sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.6)

# %%
# %precision
# Out:
# UsageError: Line magic function `%precision%3` not found.

# %%
text = TextBlob("The food is not good")
text.sentiment
# Out:
# Sentiment(polarity=-0.35, subjectivity=0.6000000000000001)

# %%
text = TextBlob("The movie was not bad")
text.sentiment
# Out:
# Sentiment(polarity=0.3499999999999999, subjectivity=0.6666666666666666)

# %%
text = TextBlob("The movie was excellent")
text.sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
from textblob.sentiments import NaiveBayesAnalyzer

blob = TextBlob("The movie was excellent",analyzer=NaiveBayesAnalyzer())
blob.sentiment
# Out:
# Sentiment(classification='pos', p_pos=0.7318278242290406, p_neg=0.26817217577095936)

# %%
from textblob import Word

index = Word("focus")
print(index.singularize())
print(index.pluralize())
# Out:
# focu
# foci

# %%
v = Word("Varieties")
v.stem()
# Out:
# 'varieti'

# %%
v.lemmatize()
# Out:
# 'Varieties'

# %%
v=[Word("good"),Word("better"),Word("worst"),Word("running"),Word("Study")]

for i in v:
    print(i,"--->",i.lemmatize(),i.stem())
# Out:
# good ---> good good
# better ---> better better
# worst ---> worst worst
# running ---> running run
# Study ---> Study studi
